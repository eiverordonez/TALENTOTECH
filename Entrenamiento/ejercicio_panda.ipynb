# %%
import pandas as pd
# Create a dataset
# Let´s build the values lists
value_m_list = ['January', 'February', 'March', 'April',"may"]
print(value_n_month)
value_s_list = [31500, 35600, 28300, 33900,45000] # [pesos]
value_b_list = [22000, 23400, 18100, 20700,35000] # [pesos]
value_e_list = [10000,15000,5000,2000,1000] # [pesos]

# Let´s use a dictionary ({key:value})
# with the format {"str":list}
data_dict = {"month":value_m_list,
             "Sales":value_s_list,
             "Bills":value_b_list,
             "earnings":value_e_list}
              #"BMI":value_bmi_list}

print(data_dict)

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

print(df)
# Call a variable
df
# Out:
# ['January', 'February', 'March', 'April', 'may']
# {'month': ['January', 'February', 'March', 'April', 'may'], 'Sales': [31500, 35600, 28300, 33900, 45000], 'Bills': [22000, 23400, 18100, 20700, 35000], 'earnings': [10000, 15000, 5000, 2000, 1000]}
#       month  Sales  Bills  earnings
# 0   January  31500  22000     10000
# 1  February  35600  23400     15000
# 2     March  28300  18100      5000
# 3     April  33900  20700      2000
# 4       may  45000  35000      1000
#       month  Sales  Bills  earnings
# 0   January  31500  22000     10000
# 1  February  35600  23400     15000
# 2     March  28300  18100      5000
# 3     April  33900  20700      2000
# 4       may  45000  35000      1000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Sales'].plot(kind='hist', bins=20, title='Sales')
# ...
